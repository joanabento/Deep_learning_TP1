# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping

# %%
#Ler os dados do dataset vinho branco
df_white = pd.read_csv('winequality-white.csv', encoding ="UTF-8", sep=';')

# %%
#Matrizes de Correlação
#Os atributos q têm alta correlação com a qualidade são bons
#Um atributo que tenham alta correlação com outro atributo podemos dar drop
corrMatrix = df_white.corr()
print(corrMatrix)
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.089021   0.023086            -0.049396
# volatile acidity            0.064286   0.070512            -0.097012
# citric acid                 0.094212   0.114364             0.094077
# residual sugar              1.000000   0.088685             0.299098
# chlorides                   0.088685   1.000000             0.101392
# free sulfur dioxide         0.299098   0.101392             1.000000
# total sulfur dioxide        0.401439   0.198910             0.615501
# density                     0.838966   0.257211             0.294210
# pH                         -0.194133  -0.090439            -0.000618
# sulphates                  -0.026664   0.016763             0.059217
# alcohol                    -0.450631  -0.360189            -0.250104
# quality                    -0.097577  -0.209934             0.008158
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                     0.091070  0.265331 -0.425858  -0.017143
# volatile acidity                  0.089261  0.027114 -0.031915  -0.035728
# citric acid                       0.121131  0.149503 -0.163748   0.062331
# residual sugar                    0.401439  0.838966 -0.194133  -0.026664
# chlorides                         0.198910  0.257211 -0.090439   0.016763
# free sulfur dioxide               0.615501  0.294210 -0.000618   0.059217
# total sulfur dioxide              1.000000  0.529881  0.002321   0.134562
# density                           0.529881  1.000000 -0.093591   0.074493
# pH                                0.002321 -0.093591  1.000000   0.155951
# sulphates                         0.134562  0.074493  0.155951   1.000000
# alcohol                          -0.448892 -0.780138  0.121432  -0.017433
# quality                          -0.174737 -0.307123  0.099427   0.053678
#
#                        alcohol   quality
# fixed acidity        -0.120881 -0.113663
# volatile acidity      0.067718 -0.194723
# citric acid          -0.075729 -0.009209
# residual sugar       -0.450631 -0.097577
# chlorides            -0.360189 -0.209934
# free sulfur dioxide  -0.250104  0.008158
# total sulfur dioxide -0.448892 -0.174737
# density              -0.780138 -0.307123
# pH                    0.121432  0.099427
# sulphates            -0.017433  0.053678
# alcohol               1.000000  0.435575
# quality               0.435575  1.000000

# %%
import seaborn as sn
sn.heatmap(corrMatrix, annot=True)
plt.show()

# %%
#df_white['quality']
df_white['quality'].value_counts()
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %%
#Determinar quantos vinho têm determinada qualidade
plt.hist(df_white["quality"])
plt.ylabel('Número de Amostras')
plt.xlabel('Qualidade')
plt.show()

# %%
round(len(df_white)*0.3)
df_white = np.asarray(df_white)

# %%
#Dividir os dados em treino e em teste (70% para treino, 30% para teste)
l_treino = df_white[:int(len(df_white)*0.7),-1] 
l_test = df_white[-int(len(df_white)*0.3):,-1]

d_treino = df_white[:int(len(df_white)*0.7),:-1]
d_test = df_white[-int(len(df_white)*0.3):,:-1]

# %%
d_treino.shape
# Out:
# (3428, 11)

# %%
print(l_treino.shape)
print(l_test.shape)
print(d_treino.shape)
print(d_test.shape)
print(len(df_white))
#print(3428+1469)
# Out:
# (3428,)
# (1469,)
# (3428, 11)
# (1469, 11)
# 4898

# %%
#Normalizar os dados
from sklearn.preprocessing import MinMaxScaler

#Ajustar o formato dos dados à rede de entrada
#d_treino = d_treino.astype("float32")/255
#d_test = d_test.astype("float32")/255
scaler = MinMaxScaler()
d_treino = scaler.fit_transform(d_treino)
d_test = scaler.fit_transform(d_test)
print(d_treino)
print(d_test)
# Out:
# [[0.28       0.20540541 0.21686747 ... 0.25454545 0.27380952 0.13333333]
#  [0.21       0.23783784 0.20481928 ... 0.52727273 0.32142857 0.25      ]
#  [0.39       0.21621622 0.24096386 ... 0.49090909 0.26190476 0.35      ]
#  ...
#  [0.29       0.0972973  0.24096386 ... 0.56363636 0.66666667 0.18333333]
#  [0.29       0.0972973  0.24096386 ... 0.56363636 0.66666667 0.18333333]
#  [0.16       0.17297297 0.15662651 ... 0.55454545 0.33333333 0.53333333]]
# [[0.63461538 0.09359606 0.39       ... 0.57731959 0.63855422 0.12068966]
#  [0.63461538 0.08374384 0.4        ... 0.56701031 0.63855422 0.12068966]
#  [0.63461538 0.09359606 0.39       ... 0.56701031 0.62650602 0.12068966]
#  ...
#  [0.51923077 0.15270936 0.19       ... 0.20618557 0.25301205 0.17241379]
#  [0.32692308 0.20197044 0.3        ... 0.56701031 0.15662651 0.75862069]
#  [0.42307692 0.12315271 0.38       ... 0.48453608 0.08433735 0.5862069 ]]

# %%
#Ajustar o formato dos dados à rede de saída
from tensorflow.keras.utils import to_categorical

l_treino = to_categorical(l_treino)
l_test = to_categorical(l_test)

# %%
l_treino = np.asarray(l_treino)
l_test = np.asarray(l_test)
d_treino = np.asarray(d_treino)
d_test = np.asarray(d_test)
print(d_treino.shape)
# Out:
# (3428, 11)

# %%
print(l_treino.shape)  #COMO DÁ 10???????
print(d_treino.shape)
# Out:
# (3428, 10)
# (3428, 11)

# %%
#Rede com Overfit
from tensorflow.keras import models
from tensorflow.keras import layers

rede = models.Sequential()
rede.add(layers.Dense(64, activation="relu",input_shape=(11,)))
rede.add(layers.Dense(128, activation="relu"))
rede.add(layers.Dense(256, activation="relu"))
rede.add(layers.Dense(512, activation="relu"))
rede.add(layers.Dense(256, activation="relu"))
rede.add(layers.Dense(128, activation="relu"))
rede.add(layers.Dense(10, activation="sigmoid"))

rede.compile(optimizer="rmsprop",
            loss="binary_crossentropy",
            metrics=["accuracy"])

# %%
#Treino de experiencia
rede.fit(x=d_treino,y=l_treino, epochs=120, validation_data=(d_test,l_test), batch_size=128)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-3c79effa2a8f> in <module>
#       1 #Treino de experiencia
# ----> 2 rede.fit(x=d_treino,y=l_treino, epochs=120, validation_data=(d_test,l_test), batch_size=128)
#
# ~\anaconda3\envs\dp\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# ~\anaconda3\envs\dp\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     233           max_queue_size=max_queue_size,
#     234           workers=workers,
# --> 235           use_multiprocessing=use_multiprocessing)
#     236
#     237       total_samples = _get_total_number_of_samples(training_data_adapter)
#
# ~\anaconda3\envs\dp\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in _process_training_inputs(model, x, y, batch_size, epochs, sample_weights, class_weights, steps_per_epoch, validation_split, validation_data, validation_steps, shuffle, distribution_strategy, max_queue_size, workers, use_multiprocessing)
#     612           class_weights=class_weights,
#     613           steps=validation_steps,
# --> 614           distribution_strategy=distribution_strategy)
#     615     elif validation_steps:
#     616       raise ValueError('`validation_steps` should not be specified if '
#
# ~\anaconda3\envs\dp\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in _process_inputs(model, mode, x, y, batch_size, epochs, sample_weights, class_weights, shuffle, steps, distribution_strategy, max_queue_size, workers, use_multiprocessing)
#     644     standardize_function = None
#     645     x, y, sample_weights = standardize(
# --> 646         x, y, sample_weight=sample_weights)
#     647   elif adapter_cls is data_adapter.ListsOfScalarsDataAdapter:
#     648     standardize_function = standardize
#
# ~\anaconda3\envs\dp\lib\site-packages\tensorflow_core\python\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split, shuffle, extract_tensors_from_dataset)
#    2381         is_dataset=is_dataset,
#    2382         class_weight=class_weight,
# -> 2383         batch_size=batch_size)
#    2384
#    2385   def _standardize_tensors(self, x, y, sample_weight, run_eagerly, dict_inputs,
#
# ~\anaconda3\envs\dp\lib\site-packages\tensorflow_core\python\keras\engine\training.py in _standardize_tensors(self, x, y, sample_weight, run_eagerly, dict_inputs, is_dataset, class_weight, batch_size)
#    2487           # Additional checks to avoid users mistakenly using improper loss fns.
#    2488           training_utils.check_loss_and_target_compatibility(
# -> 2489               y, self._feed_loss_fns, feed_output_shapes)
#    2490
#    2491       sample_weights, _, _ = training_utils.handle_partial_sample_weights(
#
# ~\anaconda3\envs\dp\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py in check_loss_and_target_compatibility(targets, loss_fns, output_shapes)
#     808           raise ValueError('A target array with shape ' + str(y.shape) +
#     809                            ' was passed for an output of shape ' + str(shape) +
# --> 810                            ' while using as loss `' + loss_name + '`. '
#     811                            'This loss expects targets to have the same shape '
#     812                            'as the output.')
#
# ValueError: A target array with shape (1469, 9) was passed for an output of shape (None, 10) while using as loss `binary_crossentropy`. This loss expects targets to have the same shape as the output.

# %%
resultados = r.evaluate(d_test, l_test)

# %%
import matplotlib.pyplot as plt

# %%
rede

# %%
print(r.history.history.keys())
plt.plot(r.history.history['loss'],label = 'train loss')
plt.plot(r.history.history['val_loss'],label = 'val_loss')
plt.title('Train vs val')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
#plt.savefig(dire+'/Loss.png')
plt.show()

# %%
print(r.history.history.keys())
plt.plot(r.history.history['accuracy'],label = 'train accuracy')
plt.plot(r.history.history['val_accuracy'],label = 'val_accuracy')
plt.title('Train vs val')
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
#plt.savefig(dire+'/Loss.png')
plt.show()

# %%
print(d_test[0,:].shape)
for i in range(10):
    pred_sample = d_test[i]
    pred_sample = np.reshape(pred_sample,(1,11))
    prediction = r.predict(pred_sample)
    print('rede preveu:' + str(prediction.argmax()) + '  --- valor real é:' + str(l_test[i].argmax()))
